# %% [markdown]
# # <center><U><B>Pharmaceutical Manufacturing Sales Analysis USING ML 💊</B></U></center>
#
# ###<center><B><U>**MSC DATA SCIENCE**</center></U>
#
#  ✍ This Project is Performed Under Guidance of - <U>**SWASTI DESAI**</U>
#  - **Abdul Awwal Choudhari**

# %% [markdown]
# ![pharmaceutical-industry (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##**Steps Performed -**
#
# - **Data Collection**
# - **Data Cleaning and preprocessing**
# - **Exploratory Data Analysis (EDA)**
# - **Modelling**
# - **Model Evaluation**
# - **Model Tuning and Optimization**
# - **Interpretation of Results**

# %% [markdown]
# # **Introduction**

# %% [markdown]
#  💊 **Foresight Pharmaceuticals** is one of the leading Pharmaceutical
#    Manufacturing companies with a global presence.
#
# 💊 Their Markets are divided into different regions across the world. One of those regions manages the **Germany** and **Poland Markets**.
#
# 💊 But the company does **not sell directly to customers**. Instead, they work with a couple of Distributors in all their regions.
#
# 💊 They have an agreement with each of the distributor to share their Sales Data with them. This to enable them gain insights up to the retail level.
#
# 💊 The products are sold through **2 channels(DEPARTMENT) - hospital, pharmacy** - and
#    through
#  💊 **4 sub-channels - government, institution, private and retail**.
#
# 💊 The **dataset contains** sales figures, as well as distributor names, sales channel and sub-channel, sales team, and so on for
#
#    **years 2017 through to 2020**.

# %% [markdown]
# # **ABOUT DATASET**
# **We Cleaned the dataset in Excel .**
# - Handled negative values in Quantities. 2660 values drop. (254082)
# - Decimal values converted into integers (Quantity, longitude & latitude).
#
# **After Cleaning:-**
#
# - Total **18** Features (Columns) present.
# - Total **251448** records are present.
# - **Sales** feature is our target Variable.
# -No Missing Value present.
# - Below are the **descriptions** of every features.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![1680158752971.png](data:image/png;base64,...)

# %% [markdown]
# ▶ **Categorical/Qualitative Data:**
#
# **Ordinal Data:**
# - Channel
# - Year
#
# **Nominal Data**
# - Distributor
# - Customer Name
# - City
# - Country
# - Product Name
# - Name of Sales Rep
# - Manager
# - Sales Team
# - Channel
# - Sub-channel
#
# ▶ **Quantitative Data:**
# - Latitude
# - Longitude
# - Price
# - Sales
#
# ▶ **Discrete** **Data**:
# - Quantity
# - Month

# %% [markdown]
# # **Import Liabraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
#Reading the CSV file

df = pd.read_csv('/content/Pharm Data1 (1).csv')

# Display the first 5 rows of the DataFrame
df.head(5)
# Out:
#               Distributor                         Customer Name     City  \
# 0  Gottlieb-Cruickshank                 Zieme, Doyle and Kunze    Lublin
# 1  Gottlieb-Cruickshank                              Feest PLC   ?wiecie
# 2  Gottlieb-Cruickshank    Medhurst-Beer Pharmaceutical Limited   Rybnik
# 3  Gottlieb-Cruickshank                   Barton Ltd Pharma Plc  Czelad?
# 4  Gottlieb-Cruickshank                    Keeling LLC Pharmacy  Olsztyn
#
#   Country  Latitude  Longitude   Channel  Sub-channel            Product Name  \
# 0  Poland   51.2333    22.5667  Hospital      Private              Topipizole
# 1  Poland   53.4167    18.4333  Pharmacy       Retail            Choriotrisin
# 2  Poland   50.0833    18.5000  Pharmacy  Institution               Acantaine
# 3  Poland   50.3333    19.0833  Hospital      Private    Lioletine Refliruvax
# 4  Poland   53.7800    20.4942  Pharmacy       Retail  Oxymotroban Fexoformin
#
# ...

# %% [markdown]
# **Discriptive Statistics About Our Data**

# %%
df.shape
# Out:
# (254082, 18)

# %% [markdown]
# **Total Unique Values in Data are**
# - Total Revenue - **11.8 bn $**
# - Distributor - **29**
# - City - **749**
# - Country - **2**
# - Channel - **2**
# - sub channel - **4**
# - Product name - **240**
# - Product class - **6**
# - Manager - **4**
# - Sales Team - **4**
#
# ![image.png](data:image/png;base64,...)

# %%
df.describe(include='all')

# also detect the outliers in this code with the help of standard deviation
# NAN (for object not countable)
# Out:
#          Distributor                 Customer Name       City  Country  \
# count         254082                        254082     254082   254082
# unique            29                           751        749        2
# top     Gerlach LLC   Spinka, Schowalter and Conn   Friedberg  Germany
# freq          111364                           440        796   213598
# mean             NaN                           NaN        NaN      NaN
# std              NaN                           NaN        NaN      NaN
# min              NaN                           NaN        NaN      NaN
# 25%              NaN                           NaN        NaN      NaN
# 50%              NaN                           NaN        NaN      NaN
# 75%              NaN                           NaN        NaN      NaN
# max              NaN                           NaN        NaN      NaN
#
#              Latitude      Longitude   Channel Sub-channel Product Name  \
# ...

# %%
# There are Total 12 Objects and 6 numeric columns-
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254082 entries, 0 to 254081
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Distributor        254082 non-null  object
#  1   Customer Name      254082 non-null  object
#  2   City               254082 non-null  object
#  3   Country            254082 non-null  object
#  4   Latitude           254082 non-null  float64
#  5   Longitude          254082 non-null  float64
#  6   Channel            254082 non-null  object
#  7   Sub-channel        254082 non-null  object
#  8   Product Name       254082 non-null  object
#  9   Product Class      254082 non-null  object
#  10  Quantity           254082 non-null  float64
#  11  Price              254082 non-null  int64
#  12  Sales              254082 non-null  float64
#  13  Month              254082 non-null  object
#  14  Year               254082 non-null  int64
# ...

# %%
df.isnull().sum()             # No missing values-
# Out:
# Distributor          0
# Customer Name        0
# City                 0
# Country              0
# Latitude             0
# Longitude            0
# Channel              0
# Sub-channel          0
# Product Name         0
# Product Class        0
# Quantity             0
# Price                0
# Sales                0
# Month                0
# Year                 0
# Name of Sales Rep    0
# Manager              0
# Sales Team           0
# dtype: int64

# %%
df.duplicated().sum()                  # 4 duplicate values are there
# Out:
# 4

# %%
df=df.drop_duplicates()         # dropping duplicate values

# %% [markdown]
# # **Exploratory data analysis (EDA)**

# %% [markdown]
# ## **Country**
# - **Maximum Manufacturing and sales are in Country Germany with 94.26%.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![germany-pin-world-map.webp](data:image/webp;base64,...)

# %%
plt.figure(figsize=(7,4))     # almost 94% sales in Germany
sns.countplot(x = "Country", data=df, hue='Country')
plt.show()

# %% [markdown]
# ## ▶ **Distributors (29) present in Countries-**
# - **13** Distributors are there in **Poland**.
# - While **16** Distributors are there in **Germany**.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Top 5 Distributors with maximum sales are:-**
# -  Gerlach LLC
# -  Koss
# -  Erdman
# - Kozey-Emmerich
# - Romaguera-Fay
# - Beier (Poland)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ▶**Total revenue generated by channels-**
#
# -  **Pharmacy** generated **52.4%** of the total revenue
# - while **hospital** channel generated **47.6%** of the total revenue.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ▶**Total revenue generated by Sub channels (Sectors)-**
# - In Retail Sector Maximum Revenue is generated.
# - Government Sector is 2nd with 26% Revenue.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Revenue Over The Year & Months**

# %% [markdown]
# To display the monthly sales revenue for each year, we have used the **Pivot** **Table** feature in Excel. **Pivot Table** feature is a powerful tool that allows you to summarize and analyze large sets of data quickly and easily.
# - It shows revenue generated over the years where the **highest monthly sales** revenue was made in August 2019
# - **January 2019** recorded the lowest monthly sales with (**98 M**).
# - Highest Sales : Year 2018 (almost **354 M**) .

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2018 see max sales. (Pie Plot)
Country_counts = df['Year'].value_counts()
plt.figure(figsize=(8,3))
plt.pie(Country_counts, labels=Country_counts.index, autopct='%1.1f%%', startangle=240)
plt.title('Year_Pie_charts')
plt.axis('equal')  # it ensure that the pie chart is circular.
plt.show()

# %% [markdown]
# ##**Product Class (Drugs):**🍏
# - **Analgesics-** Painkiller, is a drugs which used to achieve relief from pain.
# - **Antiseptics-** Like Dettol Liquid is a effective concentrated antiseptic solution that kills bacteria and germs.
# - **Mood Stabilizers-** a person's mood changes from a depressed feeling then use.
# - **With almost 2.3 B $ Analgesics drug has highest sales.**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Products Sales-**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Manager**
# - **Maximum sales done by Britanny Bold with (3.6 B$)Sales.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Sales Team**
# - **The most impressive sales performance for the sales teams goes to the Delta team.**
# -**The Delta team successfully maintained rank 1 in performance for four years consecutively.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Pair Plot**
# - Check data scatter between two features.
# - Columns vs Columns
#
# **Every independent variable (Sales) should have a linear relationship with every dependent variable..**

# %%
sns.pairplot(df, x_vars=['Latitude','Longitude','Quantity', 'Price', 'Sales','Year'],
                 y_vars="Sales", kind='reg', palette='afmhot')
plt.show()

# %% [markdown]
# ## **BOXPLOT**
# **No Outliers Present in-**
#
# - **Price**
# - **Latitude**
# - **Year**
# - **Longitude have but we can consider**

# %%
plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Price',color='green')
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Year',color='green')
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Latitude',color='green')
plt.show()

# %%
# 1.3 Positivly SKewed -- df['Longitude'].skew()
# But distribution Looks similar to Normal Distribution we can consider..

plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Longitude',color='red')
plt.grid()
plt.show()

# %%
# total 12 values more than 39000

plt.figure(figsize=(18,7))
sns.boxplot(data=df, x='Quantity',color='red')
plt.show()

# %%
# 1 sales value is above 31000000 $ (i.e- outlier) -- 47012000
# Skewness -- 45.4 (highly positive skewed)   -- df['Sales'].skew()

plt.figure(figsize=(6,3))
sns.boxplot(data=df, x='Sales',color='red')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df)
plt.title('All Box Plot for Numeric features')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# # **PreProcessing data**
# - **Categorical to numerical conversion**.
# - **Help of label-encoder**.
# - **Label encoding assigns a unique integer to each category**
# - **One-hot encoding creates a separate column for each category (0,1)**
#
# ![image.png](data:image/png;base64,...)

# %%
# show the number of object/Categorical features present.
# 12 Feature are Categorical

colname=[]
for x in df.columns:
    if df[x].dtype=='object':
        colname.append(x)
colname
# Out:
# ['Distributor',
#  'Customer Name',
#  'City',
#  'Country',
#  'Channel',
#  'Sub-channel',
#  'Product Name',
#  'Product Class',
#  'Month',
#  'Name of Sales Rep',
#  'Manager',
#  'Sales Team']

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

for x in colname:
    df[x]=le.fit_transform(df[x])

# %%
df.info()          # Now we can see that there is No feature which belongs to object data-type.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251444 entries, 0 to 251447
# Data columns (total 18 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Distributor        251444 non-null  int64
#  1   Customer Name      251444 non-null  int64
#  2   City               251444 non-null  int64
#  3   Country            251444 non-null  int64
#  4   Latitude           251444 non-null  float64
#  5   Longitude          251444 non-null  float64
#  6   Channel            251444 non-null  int64
#  7   Sub-channel        251444 non-null  int64
#  8   Product Name       251444 non-null  int64
#  9   Product Class      251444 non-null  int64
#  10  Quantity           251444 non-null  float64
#  11  Price              251444 non-null  int64
#  12  Sales              251444 non-null  float64
#  13  Month              251444 non-null  int64
#  14  Year               251444 non-null  int64
# ...

# %%
df.head(5)    # now we can see that it is converted in numeric form.
# Out:
#    Distributor  Customer Name  City  Country  Latitude  Longitude  Channel  \
# 0           13            497    40        0   50.9000     6.1833        1
# 1            0            745   123        0   53.8667     8.7000        1
# 2            0            654    77        0   51.5232     6.9253        1
# 3           13            520   684        0   49.5561     8.6697        0
# 4           13            663   382        0   50.3833     8.0667        1
#
#    Sub-channel  Product Name  Product Class  Quantity  Price       Sales  \
# 0            3           214              2   92000.0    511  47012000.0
# 1            3            46              5   58800.0    513  30164400.0
# 2            3            38              3   58100.0    487  28294700.0
# 3            0           214              2   50000.0    511  25550000.0
# 4            3           203              0   46000.0    529  24334000.0
#
#    Month  Year  Name of Sales Rep  Manager  Sales Team
# ...

# %% [markdown]
# ## <b>Define X (independent variable) and y (Dependent variable) </b>

# %%
# Customer name does not impact anything. So we are not considering it.

X=df[['Distributor', 'City', 'Country', 'Latitude',
       'Longitude', 'Channel', 'Sub-channel', 'Product Name', 'Product Class',
       'Quantity', 'Price', 'Month', 'Year', 'Name of Sales Rep',
       'Manager', 'Sales Team']]

y =df['Sales']

# %% [markdown]
# ## **- The dependent variable (Sales) should follow an approximate normal distribution.**

# %%
# It seems Slightly Positively skewed.
plt.figure(figsize=(10,6))
sns.distplot(y, hist=True, kde=True)
plt.show()

# with the help of log make it normal distribution

# %%
y = np.log1p(y)      # Use Log function to make Sales feautures as Normal Distribution.
y.hist();            # Machine understands and predict ND easily.

# %%
# after use of log funtion our graph looks ND.
plt.figure(figsize=(10,6))
sns.distplot(y, hist=True, kde=True, color='green')
plt.show()

# with the help of log we made it normal distribution

# %% [markdown]
# ## **To check Skewness in 'X'**
# ### **To check the data is heavyly skewed (right or left) in x variables.**

# %%
from scipy.stats import skew
#finding the skewness in each variables
data_num_skew=X.apply(lambda x: skew(x.dropna()))

#subsetting the variables that are highly skewed
data_num_skewed=data_num_skew[(data_num_skew>.75 ) | (data_num_skew<-.75)]

print(data_num_skew)
print(data_num_skewed)

import numpy as np
#apply log +1 transformation for all numeric features with skewness over.75
X[data_num_skewed.index]= np.log1p(X[data_num_skewed.index])
# Out:
# Distributor           1.603796
# City                  0.019794
# Country               1.845523
# Latitude             -0.080481
# Longitude             1.319131
# Channel              -0.045748
# Sub-channel          -0.003136
# Product Name         -0.001224
# Product Class        -0.123813
# Quantity             44.890454
# Price                -0.108691
# Month                -0.070617
# Year                  0.257198
# Name of Sales Rep    -0.001539
# Manager               0.098429
# Sales Team           -0.130221
# dtype: float64
# Distributor     1.603796
# Country         1.845523
# Longitude       1.319131
# Quantity       44.890454
# dtype: float64

# %%
# Quantity feature is highly Skewd
data_num_skewed.index   # 4
# Out:
# Index(['Distributor', 'Country', 'Longitude', 'Quantity'], dtype='object')

# %% [markdown]
# ##**No Multicolinearity**
# - There should be no multicolinearity between the independent variables. Assumption of LR.
# -**Heatmap**
# -**VIF method**

# %%
plt.figure(figsize=(18,10))
# sns.heatmap(corr_df,vmax=1.0,vmin=-1.0,annot=True)
sns.heatmap(df.corr(), annot=True, cmap="YlGnBu" )
plt.show()

# %% [markdown]
# ## **Scaling the Data**
# - use of Standard scalar (-3 to 3)

# %%
# from sklearn.preprocessing import StandardScaler
# sc=StandardScaler()
# sc.fit(X)
# x=sc.transform(X)
# print(X)

# %% [markdown]
# ## **VIF-(Varience inflation factor**)

# %%
from statsmodels.stats.outliers_influence import  variance_inflation_factor as vif

vif_df= pd.DataFrame()
vif_df['features']=X.columns
vif_df['VIF Factor']= [vif(X.values,i) for i in range(X.shape[1])]
vif_df.round(2)
# Out:
#              features  VIF Factor
# 0         Distributor       28.61
# 1                City        3.96
# 2             Country        3.75
# 3            Latitude     1041.14
# 4           Longitude      177.07
# 5             Channel        2.69
# 6         Sub-channel        3.63
# 7        Product Name        3.99
# 8       Product Class        3.20
# 9            Quantity        5.22
# 10              Price        4.36
# 11              Month        3.75
# 12               Year     1269.83
# 13  Name of Sales Rep        3.57
# 14            Manager        4.43
# 15         Sales Team        4.67

# %% [markdown]
# **We drop 'Latitude' and 'Longitude' column and then again we check accuracy overall no improvment thats why we dont drop any column.**

# %%
# See the Vif value of Latitude -- 1041 (Very Big)

# X = X.drop(['Latitude'],axis=1)
# X = X.drop(['Longitude'],axis=1)

# %% [markdown]
# ## **Split the Data**

# %%
from sklearn.model_selection import train_test_split
#split the data into train and test
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.3, random_state=10)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (176010, 16)
# (75434, 16)
# (176010,)
# (75434,)

# %% [markdown]
# # **Linear Regression Model**

# %%
from sklearn.linear_model import LinearRegression
#create a model obj
lm=LinearRegression()
#train the model obj
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#predict using model
y_pred_new = lm.predict(X_test)
y_pred_new

lm.score(X_train,y_train)   #To check Training accuracy
# Out:
# 0.9668392611411566

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

rmse=np.sqrt(mean_squared_error(y_test,y_pred_new))
print(rmse)
# Out:
# 0.33943217890080823

# %% [markdown]
# - Nothing improve error after standard scalar..
# - no need to drop any latitude and longitude bcos it doesnt impact our error.
# - Log for Sales --- 0.33

# %%
# r2 square means that our model is 96% is accurate on test data.
from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_pred_new)*100
r_squared
print('r2_squared is :', r_squared)
# Out:
# r2_squared is : 96.7774481223063

# %% [markdown]
# ##**Extreme Gradient Boosting (XGBoost) Regressor Model**
# - Gradient boosting refers to a class of **ensemble machine learning algorithms** that can be used for classification or regression predictive modeling problems.
#
# - Ensembles are constructed from **decision tree models**.Trees are added one at a time to the ensemble and fit to correct the prediction errors made by prior models. This is a type of ensemble machine learning model referred to as boosting.
#
# - Models are fit using any arbitrary differentiable loss function and gradient descent optimization algorithm. This gives the technique its name, “gradient boosting,” as the loss gradient is minimized as the model is fit, much like a neural network.

# %%
from xgboost import XGBRegressor
XGBR = XGBRegressor(n_estimators=1000, max_depth=7)
XGBR.fit(X_train, y_train)

y_pred = XGBR.predict(X_test)
y_pred

XGBR.score(X_train,y_train)   #To check Training accuracy
# Out:
# 0.999998884119366

# %% [markdown]
# **R2-Square metric**

# %%
from sklearn.metrics import r2_score
XGB_R2 = r2_score(y_test, y_pred)*100
XGB_R2
# Out:
# 99.99605803722673

# %% [markdown]
# **Root mean square error**

# %%
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print(rmse)
# Out:
# 0.011871601569554784

# %% [markdown]
# ##**Displaying** **the** **accuracy** **of** **both** **models**

# %%
accuracy_df = pd.DataFrame({
    'Model': ['Linear Regression', 'XGBoost'],
    'R2-square': [r_squared, XGB_R2]
})
print(accuracy_df)
# Out:
#                Model  R2-square
# 0  Linear Regression  96.777448
# 1            XGBoost  99.996058

# %%
# XGB model is Best model with 99.99%.
sns.barplot(x=accuracy_df['Model'], y=accuracy_df['R2-square'])
# Out:
# <Axes: xlabel='Model', ylabel='R2-square'>

# %% [markdown]
# # **Interpretation of the results**

# %% [markdown]
# ▶ **Final Insights**
#
# listed below are the insights gained from analyzing the dataset.
# - **There are a total of 29 distributors. Germany has 16 distributors while Poland has 13 distributors. Similarly, the top 8 most performing distributors in terms of revenue are located in Germany.**
# -**The revenue generated in Germany is highly significant compared to that generated in Poland.**
# -**Germany generates a whooping 96% of the total revenue, while the remaining 6% is generated by Poland.**
# -**The top 5 cities where revenue was highest over the years are no doubt located in Germany.**
# -**The most impressive sales performance for the sales teams goes to the Delta team. The Delta team successfully maintained rank 1 in performance for four years consecutively.**
# -**Many more insights find above in EDA part.**
#
# ▶ **Recommendation**
#
# The huge disparity between the sales performance of both countries is very Outstanding.
# - Could this be because there aren't as many distributors in Poland as there are in Germany?
# -  Could it be that, in Poland, people rarely have health issues that may require them to visit the hospitals or purchase pharmaceutical products??
# - I would recommend that the management of Foresight pharmaceuticals should get **more distributors** who have the capacity to penetrate into the Poland market
# .
# - **Provide** a health awareness campaigns, dominate the market, drive sales , and as an end result,to increase revenue.
#
# - Foresight pharmaceuticals should **increase investment in**  research and development which will lead to innovation of new pharmaceutical products which will be readily acceptable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
